# %%
# !pip install -q transformers datasets peft trl accelerate bitsandbytes
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 528.8/528.8 kB 38.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 19.2 MB/s eta 0:00:00

# %%
# !python /content/sample_data/qwen25_tool_call_finetune.py
# Out:
# Loading tokenizer ...
# config.json: 100% 659/659 [00:00<00:00, 3.37MB/s]
# tokenizer_config.json: 7.30kB [00:00, 7.97MB/s]
# vocab.json: 2.78MB [00:00, 121MB/s]
# merges.txt: 1.67MB [00:00, 127MB/s]
# tokenizer.json: 7.03MB [00:00, 166MB/s]
# Train samples: 11  |  Eval samples: 3
# Loading model ...
# ...
# model.safetensors: 100% 988M/988M [00:05<00:00, 168MB/s]
# Loading weights: 100% 290/290 [00:00<00:00, 387.87it/s, Materializing param=model.norm.weight]
# generation_config.json: 100% 242/242 [00:00<00:00, 1.41MB/s]
# Adding EOS to train dataset: 100% 11/11 [00:00<00:00, 2224.34 examples/s]
# Tokenizing train dataset: 100% 11/11 [00:00<00:00, 522.39 examples/s]
# Truncating train dataset: 100% 11/11 [00:00<00:00, 2576.35 examples/s]
# Adding EOS to eval dataset: 100% 3/3 [00:00<00:00, 1205.61 examples/s]
# Tokenizing eval dataset: 100% 3/3 [00:00<00:00, 644.32 examples/s]
# Truncating eval dataset: 100% 3/3 [00:00<00:00, 1761.33 examples/s]
#
# Starting training ...
#
# ...

# %%
# !python /content/sample_data/Qwen2.5-0.5B_tool_call_finetune_eval.py
# Out:
# Auto-detected adapter at: /content/qwen25-tool-lora/checkpoint-6
# Loading tokenizer ...
# Loading base model ...
# Loading weights: 100% 290/290 [00:00<00:00, 431.28it/s, Materializing param=model.norm.weight]
# Loading LoRA adapter ...
# Model ready.
#
# ...
#                   TOOL CALL EVALUATION RESULTS
# ...
#
# [TRAIN] Q: What's the weather like in Tokyo right now?
#   Expected : {"tool": "get_weather", "arguments": {"city": "Tokyo", "units": "celsius"}}
#   Got      : {"tool": "weather", "arguments": {"city": "Tokyo"}}
# {"tool": "weather", "arguments": {"city": "Tokyo"}}
# {"tool": "weathe
#   JSON OK  : False | Tool OK: False | Args OK: False | [FAIL]
#
# [TRAIN] Q: What is 15% of 840?
#   Expected : {"tool": "calculator", "arguments": {"expression": "0.15 * 840"}}
#   Got      : 1260
#   JSON OK  : False | Tool OK: False | Args OK: False | [FAIL]
#
# [TRAIN] Q: What's the current stock price of Apple?
#   Expected : {"tool": "get_stock_price", "arguments": {"ticker": "AAPL"}}
# ...
